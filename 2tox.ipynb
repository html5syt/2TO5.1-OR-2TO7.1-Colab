# %% [markdown]
# # 2TO5.1-OR-2TO7.1 Colab

# %%
# !rm -rf 2TO5.1-OR-2TO7.1
# !mkdir -p input
# !mkdir -p output

# %%
# 克隆仓库
# !git clone https://github.com/html5syt/2TO5.1-OR-2TO7.1-Colab.git -b beta-v3

# 安装依赖
# !python -m pip install -r ./2TO5.1-OR-2TO7.1-Colab/requirements.txt

# %%
# 下载模型文件到 models 目录
# !wget -P /content/2TO5.1-OR-2TO7.1-Colab/bsroformer/models/ https://huggingface.co/ChanTrail/BS-RoFormer/resolve/main/BS-Rofo-SW-Fixed.ckpt
# !wget -P /content/2TO5.1-OR-2TO7.1-Colab/bsroformer/models/ https://huggingface.co/ChanTrail/BS-RoFormer/resolve/main/logic_bs_roformer.ckpt
# !wget -P /content/2TO5.1-OR-2TO7.1-Colab/bsroformer/models/ https://huggingface.co/ChanTrail/BS-RoFormer/resolve/main/logic_roformer.pt

# 下载配置文件到 configs 目录
# !wget -P /content/2TO5.1-OR-2TO7.1-Colab/bsroformer/configs/ https://huggingface.co/ChanTrail/BS-RoFormer/resolve/main/BS-Rofo-SW-Fixed.yaml
# !wget -P /content/2TO5.1-OR-2TO7.1-Colab/bsroformer/configs/ https://huggingface.co/ChanTrail/BS-RoFormer/resolve/main/logic_pro_config_v1.yaml

# %%
# !python /content/2TO5.1-OR-2TO7.1/main.py
# !python /content/2TO5.1-OR-2TO7.1/bsroformer/inference.py --model_type bs_roformer --config_path /content/2TO5.1-OR-2TO7.1/bsroformer/configs/BS-Rofo-SW-Fixed.yaml --start_check_point /content/2TO5.1-OR-2TO7.1/bsroformer/models/BS-Rofo-SW-Fixed.ckpt --input_folder input --store_dir output --extract_instrumental
# !python /content/2TO5.1-OR-2TO7.1-Colab/web_mixer.py --cli --input_dir input --output_dir output --channel_count 7 --export_all

# %%
# 保活
# !sleep 15m

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p /content/drive/MyDrive/2TO5.1-OR-2TO7.1-Colab/input
# !mkdir -p /content/drive/MyDrive/2TO5.1-OR-2TO7.1-Colab/output

# %%
# !python /content/2TO5.1-OR-2TO7.1-Colab/web_mixer.py --cli --input_dir /content/drive/MyDrive/2TO5.1-OR-2TO7.1-Colab/input --output_dir /content/drive/MyDrive/2TO5.1-OR-2TO7.1-Colab/output --channel_count 7 --export_all
